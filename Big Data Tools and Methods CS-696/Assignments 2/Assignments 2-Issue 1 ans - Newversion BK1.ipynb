# %% [markdown]
# Issue 1 - Auto Fuel Economy
# You can access the U.S. ofﬁcial fuel economy for vehicles sold in U.S. at:
# https://fueleconomy.gov/feg/download.shtml
#
# You are to investigate the the fuel economy for vehicles using gasoline from the years 2000 to 2019. We are interested in the vehicles sold be the companies General Motors, Ford, Chrysler, Honda and Toyota. Note that some companies like GM and Chrysler have sub-brands. For example Cadillac and Chevrolet are GM products. The U.S. government reports MPG (miles per gallon) in three way: city, highway and combined. We are only interested in combined MPG.

# %% [markdown]
# 1. For each company collect the MPG sold by each company in the years 2000-2019. Produce the box plots per company for the MPG over those years. How do the companies compare?

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
##Path
MPG_Vehicles_CSV = './vehicles.csv'

# %%
def extractdataByyear(Year):
    cols =['year','make','comb08'] #Columns which need
    All_df = pd.read_csv(MPG_Vehicles_CSV,usecols =col)
    year_df = All_df.loc[All_df['year'].isin([Year])]
    year_df = year_df[cols] #Swap the order, Year make comb
    year_df = year_df.reset_index()
#     year_df['year'] = year_df['year'].astype('int64') 
#     year_df['comb08'] = year_df['comb08'].astype('float64') 
    return year_df

# %%
def ConvertTheType(df):
    df['Year'] = df['Year'].astype('int64') 
    df['mpg'] = df['mpg'].astype('float64') 
#     return df

# %%
def RenameBrand(df):
    df = df.apply(lambda x: x.astype(str).str.upper())
    df = df.replace('FOMOCO','FORD')
    df = df.replace('Honda','HONDA')
    df = df.replace('Toyota','TOYOTA')
    
    df = df.replace('GM','General Motors')
    df = df.replace('CHEVROLET','General Motors')
    df = df.replace('GMC','General Motors')
    df = df.replace('Cadillac','General Motors')
    df = df.replace('BUICK','General Motors')
    
    df = df.replace('Chrysler Group LLC','Chrysler')
    df = df.replace('CHEVROLET','Chrysler')
    df = df.replace('DODGE','Chrysler')
    df = df.replace('JEEP','Chrysler')
    return df

# %%
def ExtractBrandFromDF(dfs,brandName):

    if 'index' in dfs[0].columns:
        for Adf in dfs:
            Adf = Adf.drop(columns=['index'])
    
    #2000
#     dfs[0] = dfs[0].drop(columns=['index'])
    dfs[0].columns = ['Year','MfrName','mpg']
    Brand_MPG2000_df = dfs[0].loc[dfs[0]['MfrName'].isin([brandName])]
    #     Brand_MPG2000_df = dfs[0].replace('Brand','2000')
    
    #2001
#     dfs[1] = dfs[1].drop(columns=['index'])
    dfs[1].columns = ['Year','MfrName','mpg']
    Brand_MPG2001_df = dfs[1].loc[dfs[1]['MfrName'].isin([brandName])]

    #2002
#     dfs[2] = dfs[2].drop(columns=['index'])
    dfs[2].columns = ['Year','MfrName','mpg']
    Brand_MPG2002_df = dfs[2].loc[dfs[2]['MfrName'].isin([brandName])]

	#2003
#     dfs[3] = dfs[3].drop(columns=['index'])
    dfs[3].columns = ['Year','MfrName','mpg']
    Brand_MPG2003_df = dfs[3].loc[dfs[3]['MfrName'].isin([brandName])]

	#2004
    dfs[4] = dfs[4].drop(columns=['index'])
    dfs[4].columns = ['Year','MfrName','mpg']
    Brand_MPG2004_df = dfs[4].loc[dfs[4]['MfrName'].isin([brandName])]

    #2005
#     dfs[5] = dfs[5].drop(columns=['index'])
    dfs[5].columns = ['Year','MfrName','mpg']
    Brand_MPG2005_df = dfs[5].loc[dfs[5]['MfrName'].isin([brandName])]

    #2006
#     dfs[6] = dfs[6].drop(columns=['index'])
    dfs[6].columns = ['Year','MfrName','mpg']
    Brand_MPG2006_df = dfs[6].loc[dfs[6]['MfrName'].isin([brandName])]

	#2007
#     dfs[7] = dfs[7].drop(columns=['index'])
    dfs[7].columns = ['Year','MfrName','mpg']
    Brand_MPG2007_df = dfs[7].loc[dfs[7]['MfrName'].isin([brandName])]
	
	#2008
#     dfs[8] = dfs[8].drop(columns=['index'])
    dfs[8].columns = ['Year','MfrName','mpg']
    Brand_MPG2008_df = dfs[8].loc[dfs[8]['MfrName'].isin([brandName])]
	
	#2009
#     dfs[9] = dfs[9].drop(columns=['index'])
    dfs[9].columns = ['Year','MfrName','mpg']
    Brand_MPG2009_df = dfs[9].loc[dfs[9]['MfrName'].isin([brandName])]
	
	#2010
#     dfs[10] = dfs[10].drop(columns=['index'])
    dfs[10].columns = ['Year','MfrName','mpg']
    Brand_MPG2010_df = dfs[10].loc[dfs[10]['MfrName'].isin([brandName])]
	
	#2011
#     dfs[11] = dfs[11].drop(columns=['index'])
    dfs[11].columns = ['Year','MfrName','mpg']
    Brand_MPG2011_df = dfs[11].loc[dfs[11]['MfrName'].isin([brandName])]
	
	#2012
#     dfs[12] = dfs[12].drop(columns=['index'])
    dfs[12].columns = ['Year','MfrName','mpg']
    Brand_MPG2012_df = dfs[12].loc[dfs[12]['MfrName'].isin([brandName])]

    #2013
#     dfs[13] = dfs[13].drop(columns=['index'])
    dfs[13].columns = ['Year','MfrName','mpg']
    Brand_MPG2013_df = dfs[13].loc[dfs[13]['MfrName'].isin([brandName])]

    #2014
#     dfs[14] = dfs[14].drop(columns=['index'])
    dfs[14].columns = ['Year','MfrName','mpg']
    Brand_MPG2014_df = dfs[14].loc[dfs[14]['MfrName'].isin([brandName])]
    
    #2015
#     dfs[15] = dfs[15].drop(columns=['index'])
    dfs[15].columns = ['Year','MfrName','mpg']
    Brand_MPG2015_df = dfs[15].loc[dfs[15]['MfrName'].isin([brandName])]
    #2016
#     dfs[16] = dfs[16].drop(columns=['index'])
    dfs[16].columns = ['Year','MfrName','mpg']
    Brand_MPG2016_df = dfs[16].loc[dfs[16]['MfrName'].isin([brandName])]
    
    #2017
#     dfs[17] = dfs[17].drop(columns=['index'])
    dfs[17].columns = ['Year','MfrName','mpg']
    Brand_MPG2017_df = dfs[17].loc[dfs[17]['MfrName'].isin([brandName])]
    
    #2018
#     dfs[18] = dfs[18].drop(columns=['index'])
    dfs[18].columns = ['Year','MfrName','mpg']
    Brand_MPG2018_df = dfs[18].loc[dfs[18]['MfrName'].isin([brandName])]

    #2019
#     dfs[19] = dfs[19].drop(columns=['index'])
    dfs[19].columns = ['Year','MfrName','mpg']
    Brand_MPG2019_df = dfs[19].loc[dfs[19]['MfrName'].isin([brandName])]

    all_df = pd.concat([Brand_MPG2000_df,Brand_MPG2001_df,Brand_MPG2002_df,Brand_MPG2003_df,Brand_MPG2004_df,Brand_MPG2005_df,Brand_MPG2006_df,
                    Brand_MPG2007_df,Brand_MPG2008_df,Brand_MPG2009_df,Brand_MPG2010_df,Brand_MPG2011_df,Brand_MPG2012_df,
                   Brand_MPG2013_df,Brand_MPG2014_df,Brand_MPG2015_df,Brand_MPG2016_df,Brand_MPG2016_df,Brand_MPG2017_df,
                   Brand_MPG2018_df,Brand_MPG2019_df])
#     print(Brand_MPG2007_df.dtypes)
#     print(dfs[0].dtypes)
#     print(all_df.dtypes)

    
    return all_df

# %%
#Get the requirement
#2000
MPG2000_df = extractdataByyear(2000)
MPG2000_df = RenameBrand(MPG2000_df)

#2001
MPG2001_df = extractdataByyear(2001)
MPG2001_df = RenameBrand(MPG2001_df)

#2002
MPG2002_df = extractdataByyear(2002)
MPG2002_df = RenameBrand(MPG2002_df)

#2003
MPG2003_df = extractdataByyear(2003)
MPG2003_df = RenameBrand(MPG2003_df)

#2004
MPG2004_df = extractdataByyear(2004)
MPG2004_df = RenameBrand(MPG2004_df)

#2005
MPG2005_df = extractdataByyear(2005)
MPG2005_df = RenameBrand(MPG2005_df)

#2006
MPG2006_df = extractdataByyear(2006)
MPG2006_df = RenameBrand(MPG2006_df)

#2007
MPG2007_df = extractdataByyear(2007)
MPG2007_df = RenameBrand(MPG2007_df)

#2008
MPG2008_df = extractdataByyear(2008)
MPG2008_df = RenameBrand(MPG2008_df)

#2009
MPG2009_df = extractdataByyear(2009)
MPG2009_df = RenameBrand(MPG2009_df)

#2010
MPG2010_df = extractdataByyear(2010)
MPG2010_df = RenameBrand(MPG2010_df)

#2011
MPG2011_df = extractdataByyear(2011)
MPG2011_df = RenameBrand(MPG2011_df)

#2012
MPG2012_df = extractdataByyear(2012)
MPG2012_df = RenameBrand(MPG2012_df)

#2013
MPG2013_df = extractdataByyear(2013)
MPG2013_df = RenameBrand(MPG2013_df)

#2014
MPG2014_df = extractdataByyear(2014)
MPG2014_df = RenameBrand(MPG2014_df)

#2015
MPG2015_df = extractdataByyear(2015)
MPG2015_df = RenameBrand(MPG2015_df)

#2016
MPG2016_df = extractdataByyear(2016)
MPG2016_df = RenameBrand(MPG2016_df)

#2017
MPG2017_df = extractdataByyear(2017)
MPG2017_df = RenameBrand(MPG2017_df)

#2018
MPG2018_df = extractdataByyear(2018)
MPG2018_df = RenameBrand(MPG2018_df)

#2019
MPG2019_df = extractdataByyear(2019)
MPG2019_df = RenameBrand(MPG2019_df)

all_df = [MPG2000_df,MPG2001_df,MPG2002_df,MPG2003_df,MPG2004_df,MPG2005_df,MPG2006_df,MPG2007_df,MPG2008_df,MPG2009_df,
          MPG2010_df,MPG2011_df,MPG2012_df,MPG2013_df,MPG2014_df,MPG2015_df,MPG2016_df,MPG2017_df,MPG2018_df,MPG2019_df]

# %%
# FORD_All_df = ExtractBrandFromDF(all_df,'FORD')
# FORD_All_df
# newfff = FORD_All_df.drop(columns=['MfrName'])

# pd.to_numeric(newfff['Year'])
# FORD_All_df['Year'] = FORD_All_df['Year'].astype('int64') 
# FORD_All_df['mpg'] = FORD_All_df['mpg'].astype('float64') 


GM_All_df = ExtractBrandFromDF(all_df,'General Motors')
FORD_All_df = ExtractBrandFromDF(all_df,'FORD')
Chrysler_All_df = ExtractBrandFromDF(all_df,'Chrysler')
HONDA_All_df = ExtractBrandFromDF(all_df,'HONDA')
TOYOTA_All_df = ExtractBrandFromDF(all_df,'TOYOTA')

ConvertTheType(GM_All_df)
ConvertTheType(FORD_All_df)
ConvertTheType(Chrysler_All_df)
ConvertTheType(HONDA_All_df)
ConvertTheType(TOYOTA_All_df)

TOYOTA_All_df

# plt.figure(figsize=(20,6))                           # x axis = 20, y axis = 6
# plt.ylim(10, 70)
# sns.boxplot(x="Year", y="mpg",data= FORD_All_df).set_title('FORD')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-219-2ec0a93b0201> in <module>
#       8
#       9
# ---> 10 GM_All_df = ExtractBrandFromDF(all_df,'General Motors')
#      11 FORD_All_df = ExtractBrandFromDF(all_df,'FORD')
#      12 Chrysler_All_df = ExtractBrandFromDF(all_df,'Chrysler')
#
# <ipython-input-217-3b4223a7138d> in ExtractBrandFromDF(dfs, brandName)
#       1 def ExtractBrandFromDF(dfs,brandName):
#       2     #2000
# ----> 3     dfs[0] = dfs[0].drop(columns=['index'])
#       4     dfs[0].columns = ['Year','MfrName','mpg']
#       5     Brand_MPG2000_df = dfs[0].loc[dfs[0]['MfrName'].isin([brandName])]
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
# ...

# %%
#Get the requirement
#2000
MPG2000_df = pd.read_excel(MPG2000_Path,usecols =[1,9])
MPG2000_df.columns = ['MfrName','mpg']
# MPG2000_df.head()
MPG2000_df = MPG2000_df.replace('CHEVROLET','General Motors')
MPG2000_df =MPG2000_df.replace('GMC','General Motors')
MPG2000_df =MPG2000_df.replace('Cadillac','General Motors')
MPG2000_df =MPG2000_df.replace('BUICK','General Motors')

MPG2000_df = MPG2000_df.replace('CHEVROLET','Chrysler')
MPG2000_df = MPG2000_df.replace('DODGE','Chrysler')
MPG2000_df = MPG2000_df.replace('JEEP','Chrysler')

#2001
MPG2001_df = pd.read_excel(MPG2001_Path,usecols =[1,9])
MPG2001_df.columns = ['MfrName','mpg']
# MPG2000_df.head()
MPG2001_df = MPG2001_df.replace('CHEVROLET','General Motors')
MPG2001_df =MPG2001_df.replace('GMC','General Motors')
MPG2001_df =MPG2001_df.replace('Cadillac','General Motors')
MPG2001_df =MPG2001_df.replace('BUICK','General Motors')

MPG2001_df = MPG2001_df.replace('CHEVROLET','Chrysler')
MPG2001_df = MPG2001_df.replace('DODGE','Chrysler')
MPG2001_df = MPG2001_df.replace('JEEP','Chrysler')

#2002
MPG2002_df = pd.read_excel(MPG2002_Path,usecols =[1,9])
# MPG2003_df.head()
MPG2002_df.columns = ['MfrName','mpg']
MPG2002_df = MPG2002_df.replace('CHEVROLET','General Motors')
MPG2002_df =MPG2002_df.replace('GMC','General Motors')
MPG2002_df =MPG2002_df.replace('Cadillac','General Motors')
MPG2002_df =MPG2002_df.replace('BUICK','General Motors')

MPG2002_df = MPG2002_df.replace('CHEVROLET','Chrysler')
MPG2002_df = MPG2002_df.replace('DODGE','Chrysler')
MPG2002_df = MPG2002_df.replace('JEEP','Chrysler')

#2003 
MPG2003_df = pd.read_csv(MPG2003_Path, usecols=[1,10])
# MPG2003_df.head()
MPG2003_df.columns = ['MfrName','mpg']
MPG2003_df = MPG2003_df.replace('CHEVROLET','General Motors')
MPG2003_df =MPG2003_df.replace('GMC','General Motors')
MPG2003_df =MPG2003_df.replace('Cadillac','General Motors')
MPG2003_df =MPG2003_df.replace('BUICK','General Motors')

MPG2003_df = MPG2003_df.replace('CHEVROLET','Chrysler')
MPG2003_df = MPG2003_df.replace('DODGE','Chrysler')
MPG2003_df = MPG2003_df.replace('JEEP','Chrysler')

#2004
MPG2004_df = pd.read_csv(MPG2004_Path, usecols=[1,10])
# MPG2004_df.head()
MPG2004_df.columns = ['MfrName','mpg']
MPG2004_df = MPG2004_df.replace('CHEVROLET','General Motors')
MPG2004_df =MPG2004_df.replace('GMC','General Motors')
MPG2004_df =MPG2004_df.replace('Cadillac','General Motors')
MPG2004_df =MPG2004_df.replace('BUICK','General Motors')

MPG2004_df = MPG2004_df.replace('CHEVROLET','Chrysler')
MPG2004_df = MPG2004_df.replace('DODGE','Chrysler')
MPG2004_df = MPG2004_df.replace('JEEP','Chrysler')

#2005
MPG2005_df = pd.read_csv(MPG2005_Path, usecols=[1,10])
# MPG2005_df.head()
MPG2005_df.columns = ['MfrName','mpg']
MPG2005_df = MPG2005_df.replace('CHEVROLET','General Motors')
MPG2005_df =MPG2005_df.replace('GMC','General Motors')
MPG2005_df =MPG2005_df.replace('Cadillac','General Motors')
MPG2005_df =MPG2005_df.replace('BUICK','General Motors')

MPG2005_df = MPG2005_df.replace('CHEVROLET','Chrysler')
MPG2005_df = MPG2005_df.replace('DODGE','Chrysler')
MPG2005_df = MPG2005_df.replace('JEEP','Chrysler')

#2006
MPG2006_df = pd.read_csv(MPG2006_Path, usecols=[1,9])
# MPG2006_df.head()
MPG2006_df.columns = ['MfrName','mpg']
MPG2006_df = MPG2006_df.replace('CHEVROLET','General Motors')
MPG2006_df =MPG2006_df.replace('GMC','General Motors')
MPG2006_df =MPG2006_df.replace('Cadillac','General Motors')
MPG2006_df =MPG2006_df.replace('BUICK','General Motors')

MPG2006_df = MPG2006_df.replace('CHEVROLET','Chrysler')
MPG2006_df = MPG2006_df.replace('DODGE','Chrysler')
MPG2006_df = MPG2006_df.replace('JEEP','Chrysler')

#2007
MPG2007_df = pd.read_excel(MPG2007_Path, usecols=[1,10])
# MPG2007_df.head()
MPG2007_df.columns = ['MfrName','mpg']
MPG2007_df = MPG2007_df.replace('CHEVROLET','General Motors')
MPG2007_df =MPG2007_df.replace('GMC','General Motors')
MPG2007_df =MPG2007_df.replace('Cadillac','General Motors')
MPG2007_df =MPG2007_df.replace('BUICK','General Motors')

MPG2007_df = MPG2007_df.replace('CHEVROLET','Chrysler')
MPG2007_df = MPG2007_df.replace('DODGE','Chrysler')
MPG2007_df = MPG2007_df.replace('JEEP','Chrysler')

#2008
MPG2008_df = pd.read_csv(MPG2008_Path, usecols=[1,10])
# MPG2008_df.head()
MPG2008_df.columns = ['MfrName','mpg']
MPG2008_df = MPG2008_df.replace('CHEVROLET','General Motors')
MPG2008_df =MPG2008_df.replace('GMC','General Motors')
MPG2008_df =MPG2008_df.replace('Cadillac','General Motors')
MPG2008_df =MPG2008_df.replace('BUICK','General Motors')

MPG2008_df = MPG2008_df.replace('CHEVROLET','Chrysler')
MPG2008_df = MPG2008_df.replace('DODGE','Chrysler')
MPG2008_df = MPG2008_df.replace('JEEP','Chrysler')

#2009
MPG2009_df = pd.read_excel(MPG2009_Path, usecols=[1,10])
# MPG2009_df.head()
MPG2009_df.columns = ['MfrName','mpg']
MPG2009_df = MPG2009_df.replace('CHEVROLET','General Motors')
MPG2009_df =MPG2009_df.replace('GMC','General Motors')
MPG2009_df =MPG2009_df.replace('Cadillac','General Motors')
MPG2009_df =MPG2009_df.replace('BUICK','General Motors')

MPG2009_df = MPG2009_df.replace('CHEVROLET','Chrysler')
MPG2009_df = MPG2009_df.replace('DODGE','Chrysler')
MPG2009_df = MPG2009_df.replace('JEEP','Chrysler')
MPG2009_df = MPG2009_df.replace('Honda','HONDA')

#2010
MPG2010_df = pd.read_excel(MPG2010_Path, usecols=[1,11])
MPG2010_df.columns = ['MfrName','mpg']
MPG2010_df = MPG2010_df.replace('GM','General Motors')
MPG2010_df = MPG2010_df.replace('Chrysler Group LLC','Chrysler')
MPG2010_df = MPG2010_df.replace('FOMOCO','FORD')
MPG2010_df = MPG2010_df.replace('Honda','HONDA')
MPG2010_df = MPG2010_df.replace('Toyota','TOYOTA')

#2011
MPG2011_df = pd.read_excel(MPG2011_Path, usecols=[1,11])
MPG2011_df.columns = ['MfrName','mpg']
# MPG2011_df = MPG2011_df.replace('GM','General Motors')
MPG2011_df = MPG2011_df.replace('Chrysler Group LLC','Chrysler')
MPG2011_df = MPG2011_df.replace('Ford Motor Company','FORD')
MPG2011_df = MPG2011_df.replace('Honda','HONDA')
MPG2011_df = MPG2011_df.replace('Toyota','TOYOTA')

# %%
#2012
MPG2012_df = pd.read_excel(MPG2012_Path, usecols=[1,11])
# MPG2012_df.head()
MPG2012_df.columns = ['MfrName','mpg']
MPG2012_df = MPG2012_df.replace('Chrysler Group LLC','Chrysler')
MPG2012_df = MPG2012_df.replace('Ford Motor Company','FORD')
MPG2012_df = MPG2012_df.replace('Honda','HONDA')
MPG2012_df = MPG2012_df.replace('Toyota','TOYOTA')

#2013
MPG2013_df = pd.read_excel(MPG2013_Path, usecols=[1,11])
# MPG2013_df.head()
MPG2013_df.columns = ['MfrName','mpg']
MPG2013_df = MPG2013_df.replace('Chrysler Group LLC','Chrysler')
MPG2013_df = MPG2013_df.replace('Ford Motor Company','FORD')
MPG2013_df = MPG2013_df.replace('Honda','HONDA')
MPG2013_df = MPG2013_df.replace('Toyota','TOYOTA')

#2014
MPG2014_df = pd.read_excel(MPG2014_Path, usecols=[1,11])
# MPG2014_df.head()
MPG2014_df.columns = ['MfrName','mpg']
MPG2014_df = MPG2014_df.replace('Chrysler Group LLC','Chrysler')
MPG2014_df = MPG2014_df.replace('Ford Motor Company','FORD')
MPG2014_df = MPG2014_df.replace('Honda','HONDA')
MPG2014_df = MPG2014_df.replace('Toyota','TOYOTA')

#2015
MPG2015_df = pd.read_excel(MPG2015_Path, usecols=[1,11])
# MPG2015_df.head()
MPG2015_df.columns = ['MfrName','mpg']
MPG2015_df = MPG2015_df.replace('FCA US LLC','Chrysler')
MPG2015_df = MPG2015_df.replace('Ford Motor Company','FORD')
MPG2015_df = MPG2015_df.replace('Honda','HONDA')
MPG2015_df = MPG2015_df.replace('Toyota','TOYOTA')

#2016
MPG2016_df = pd.read_excel(MPG2016_Path, usecols=[1,11])
# MPG2016_df.head()
MPG2016_df.columns = ['MfrName','mpg']
MPG2016_df = MPG2016_df.replace('FCA US LLC','Chrysler')
MPG2016_df = MPG2016_df.replace('Ford Motor Company','FORD')
MPG2016_df = MPG2016_df.replace('Honda','HONDA')
MPG2016_df = MPG2016_df.replace('Toyota','TOYOTA')

#2017
MPG2017_df = pd.read_excel(MPG2017_Path, usecols=[1,11])
# MPG2017_df.head()
MPG2017_df.columns = ['MfrName','mpg']
MPG2017_df = MPG2017_df.replace('FCA US LLC','Chrysler')
MPG2017_df = MPG2017_df.replace('Ford Motor Company','FORD')
MPG2017_df = MPG2017_df.replace('Honda','HONDA')
MPG2017_df = MPG2017_df.replace('Toyota','TOYOTA')

#2018
MPG2018_df = pd.read_excel(MPG2018_Path, usecols=[1,11])
# MPG2018_df.head()
MPG2018_df.columns = ['MfrName','mpg']
MPG2018_df = MPG2018_df.replace('FCA US LLC','Chrysler')
MPG2018_df = MPG2018_df.replace('Ford Motor Company','FORD')
MPG2018_df = MPG2018_df.replace('Honda','HONDA')
MPG2018_df = MPG2018_df.replace('Toyota','TOYOTA')

#2019
MPG2019_df = pd.read_excel(MPG2019_Path, usecols=[1,11])
# MPG2019_df.head()
MPG2019_df.columns = ['MfrName','mpg']
MPG2019_df = MPG2019_df.replace('FCA US LLC','Chrysler')
MPG2019_df = MPG2019_df.replace('Ford Motor Company','FORD')
MPG2019_df = MPG2019_df.replace('Honda','HONDA')
MPG2019_df = MPG2019_df.replace('Toyota','TOYOTA')

# %%
#FORD Data
#2000
FORD_MPG2000_df = MPG2000_df.loc[MPG2000_df['MfrName'].isin(["FORD"])]
FORD_MPG2000_df.columns = ['Year','mpg']
FORD_MPG2000_df = FORD_MPG2000_df.replace('FORD','2000')

#2001
FORD_MPG2001_df = MPG2001_df.loc[MPG2001_df['MfrName'].isin(["FORD"])]
FORD_MPG2001_df.columns = ['Year','mpg']
FORD_MPG2001_df = FORD_MPG2001_df.replace('FORD','2001')

#2002
FORD_MPG2002_df = MPG2002_df.loc[MPG2002_df['MfrName'].isin(["FORD"])]
FORD_MPG2002_df.columns = ['Year','mpg']
FORD_MPG2002_df = FORD_MPG2002_df.replace('FORD','2002')

#2003
FORD_MPG2003_df = MPG2003_df.loc[MPG2003_df['MfrName'].isin(["FORD"])]
FORD_MPG2003_df.columns = ['Year','mpg']
FORD_MPG2003_df = FORD_MPG2003_df.replace('FORD','2003')

#2004
FORD_MPG2004_df = MPG2004_df.loc[MPG2004_df['MfrName'].isin(["FORD"])]
FORD_MPG2004_df.columns = ['Year','mpg']
FORD_MPG2004_df = FORD_MPG2004_df.replace('FORD','2004')

#2005
FORD_MPG2005_df = MPG2005_df.loc[MPG2005_df['MfrName'].isin(["FORD"])]
FORD_MPG2005_df.columns = ['Year','mpg']
FORD_MPG2005_df = FORD_MPG2005_df.replace('FORD','2005')

#2006
FORD_MPG2006_df = MPG2006_df.loc[MPG2006_df['MfrName'].isin(["FORD"])]
FORD_MPG2006_df.columns = ['Year','mpg']
FORD_MPG2006_df = FORD_MPG2006_df.replace('FORD','2006')

#2007
FORD_MPG2007_df = MPG2007_df.loc[MPG2007_df['MfrName'].isin(["FORD"])]
FORD_MPG2007_df.columns = ['Year','mpg']
FORD_MPG2007_df = FORD_MPG2007_df.replace('FORD','2007')

#2008
FORD_MPG2008_df = MPG2008_df.loc[MPG2008_df['MfrName'].isin(["FORD"])]
FORD_MPG2008_df.columns = ['Year','mpg']
FORD_MPG2008_df = FORD_MPG2008_df.replace('FORD','2008')

#2009
FORD_MPG2009_df = MPG2009_df.loc[MPG2009_df['MfrName'].isin(["FORD"])]
FORD_MPG2009_df.columns = ['Year','mpg']
FORD_MPG2009_df = FORD_MPG2009_df.replace('FORD','2009')

#2010
FORD_MPG2010_df = MPG2010_df.loc[MPG2010_df['MfrName'].isin(["FORD"])]
FORD_MPG2010_df.columns = ['Year','mpg']
FORD_MPG2010_df = FORD_MPG2010_df.replace('FORD','2010')

#2011
FORD_MPG2011_df = MPG2011_df.loc[MPG2011_df['MfrName'].isin(["FORD"])]
FORD_MPG2011_df.columns = ['Year','mpg']
FORD_MPG2011_df = FORD_MPG2011_df.replace('FORD','2011')

#2012
FORD_MPG2012_df = MPG2012_df.loc[MPG2012_df['MfrName'].isin(["FORD"])]
FORD_MPG2012_df.columns = ['Year','mpg']
FORD_MPG2012_df = FORD_MPG2012_df.replace('FORD','2012')

#2013
FORD_MPG2013_df = MPG2013_df.loc[MPG2013_df['MfrName'].isin(["FORD"])]
FORD_MPG2013_df.columns = ['Year','mpg']
FORD_MPG2013_df = FORD_MPG2013_df.replace('FORD','2013')

#2014
FORD_MPG2014_df = MPG2014_df.loc[MPG2014_df['MfrName'].isin(["FORD"])]
FORD_MPG2014_df.columns = ['Year','mpg']
FORD_MPG2014_df = FORD_MPG2014_df.replace('FORD','2014')

#2015
FORD_MPG2015_df = MPG2015_df.loc[MPG2015_df['MfrName'].isin(["FORD"])]
FORD_MPG2015_df.columns = ['Year','mpg']
FORD_MPG2015_df = FORD_MPG2015_df.replace('FORD','2015')

#2016
FORD_MPG2016_df = MPG2016_df.loc[MPG2016_df['MfrName'].isin(["FORD"])]
FORD_MPG2016_df.columns = ['Year','mpg']
FORD_MPG2016_df = FORD_MPG2016_df.replace('FORD','2016')

#2017
FORD_MPG2017_df = MPG2017_df.loc[MPG2017_df['MfrName'].isin(["FORD"])]
FORD_MPG2017_df.columns = ['Year','mpg']
FORD_MPG2017_df = FORD_MPG2017_df.replace('FORD','2017')

#2018
FORD_MPG2018_df = MPG2018_df.loc[MPG2018_df['MfrName'].isin(["FORD"])]
FORD_MPG2018_df.columns = ['Year','mpg']
FORD_MPG2018_df = FORD_MPG2018_df.replace('FORD','2018')

#2019
FORD_MPG2019_df = MPG2019_df.loc[MPG2019_df['MfrName'].isin(["FORD"])]
FORD_MPG2019_df.columns = ['Year','mpg']
FORD_MPG2019_df = FORD_MPG2019_df.replace('FORD','2019')

# %%
plt.figure(figsize=(20,6))                           # x axis = 20, y axis = 6
plt.ylim(10, 70)
all_df = pd.concat([FORD_MPG2000_df,FORD_MPG2001_df,FORD_MPG2002_df,FORD_MPG2003_df,FORD_MPG2004_df,FORD_MPG2005_df,FORD_MPG2006_df,
                    FORD_MPG2007_df,FORD_MPG2008_df,FORD_MPG2009_df,FORD_MPG2010_df,FORD_MPG2011_df,FORD_MPG2012_df,
                   FORD_MPG2013_df,FORD_MPG2014_df,FORD_MPG2015_df,FORD_MPG2016_df,FORD_MPG2016_df,FORD_MPG2017_df,
                   FORD_MPG2018_df,FORD_MPG2019_df])
sns.boxplot(x="Year", y="mpg",data= all_df).set_title('FORD')
# Out:
# Text(0.5, 1.0, 'FORD')

# %%
#General Motors Data
#2000
GM_MPG2000_df = MPG2000_df.loc[MPG2000_df['MfrName'].isin(["General Motors"])]
GM_MPG2000_df.columns = ['Year','mpg']
GM_MPG2000_df = GM_MPG2000_df.replace('General Motors','2000')

#2001
GM_MPG2001_df = MPG2001_df.loc[MPG2001_df['MfrName'].isin(["General Motors"])]
GM_MPG2001_df.columns = ['Year','mpg']
GM_MPG2001_df = GM_MPG2001_df.replace('General Motors','2001')

#2002
GM_MPG2002_df = MPG2002_df.loc[MPG2002_df['MfrName'].isin(["General Motors"])]
GM_MPG2002_df.columns = ['Year','mpg']
GM_MPG2002_df = GM_MPG2002_df.replace('General Motors','2002')

#2003
GM_MPG2003_df = MPG2003_df.loc[MPG2003_df['MfrName'].isin(["General Motors"])]
GM_MPG2003_df.columns = ['Year','mpg']
GM_MPG2003_df = GM_MPG2003_df.replace('General Motors','2003')

#2004
GM_MPG2004_df = MPG2004_df.loc[MPG2004_df['MfrName'].isin(["General Motors"])]
GM_MPG2004_df.columns = ['Year','mpg']
GM_MPG2004_df = GM_MPG2004_df.replace('General Motors','2004')

#2005
GM_MPG2005_df = MPG2005_df.loc[MPG2005_df['MfrName'].isin(["General Motors"])]
GM_MPG2005_df.columns = ['Year','mpg']
GM_MPG2005_df = GM_MPG2005_df.replace('General Motors','2005')

#2006
GM_MPG2006_df = MPG2006_df.loc[MPG2006_df['MfrName'].isin(["General Motors"])]
GM_MPG2006_df.columns = ['Year','mpg']
GM_MPG2006_df = GM_MPG2006_df.replace('General Motors','2006')

#2007
GM_MPG2007_df = MPG2007_df.loc[MPG2007_df['MfrName'].isin(["General Motors"])]
GM_MPG2007_df.columns = ['Year','mpg']
GM_MPG2007_df = GM_MPG2007_df.replace('General Motors','2007')

#2008
GM_MPG2008_df = MPG2008_df.loc[MPG2008_df['MfrName'].isin(["General Motors"])]
GM_MPG2008_df.columns = ['Year','mpg']
GM_MPG2008_df = GM_MPG2008_df.replace('General Motors','2008')

#2009
GM_MPG2009_df = MPG2009_df.loc[MPG2009_df['MfrName'].isin(["General Motors"])]
GM_MPG2009_df.columns = ['Year','mpg']
GM_MPG2009_df = GM_MPG2009_df.replace('General Motors','2009')

#2010
GM_MPG2010_df = MPG2010_df.loc[MPG2010_df['MfrName'].isin(["General Motors"])]
GM_MPG2010_df.columns = ['Year','mpg']
GM_MPG2010_df = GM_MPG2010_df.replace('General Motors','2010')

#2011
GM_MPG2011_df = MPG2011_df.loc[MPG2011_df['MfrName'].isin(["General Motors"])]
GM_MPG2011_df.columns = ['Year','mpg']
GM_MPG2011_df = GM_MPG2011_df.replace('General Motors','2011')

#2012
GM_MPG2012_df = MPG2012_df.loc[MPG2012_df['MfrName'].isin(["General Motors"])]
GM_MPG2012_df.columns = ['Year','mpg']
GM_MPG2012_df = GM_MPG2012_df.replace('General Motors','2012')

#2013
GM_MPG2013_df = MPG2013_df.loc[MPG2013_df['MfrName'].isin(["General Motors"])]
GM_MPG2013_df.columns = ['Year','mpg']
GM_MPG2013_df = GM_MPG2013_df.replace('General Motors','2013')

#2014
GM_MPG2014_df = MPG2014_df.loc[MPG2014_df['MfrName'].isin(["General Motors"])]
GM_MPG2014_df.columns = ['Year','mpg']
GM_MPG2014_df = GM_MPG2014_df.replace('General Motors','2014')

#2015
GM_MPG2015_df = MPG2015_df.loc[MPG2015_df['MfrName'].isin(["General Motors"])]
GM_MPG2015_df.columns = ['Year','mpg']
GM_MPG2015_df = GM_MPG2015_df.replace('General Motors','2015')

#2016
GM_MPG2016_df = MPG2016_df.loc[MPG2016_df['MfrName'].isin(["General Motors"])]
GM_MPG2016_df.columns = ['Year','mpg']
GM_MPG2016_df = GM_MPG2016_df.replace('General Motors','2016')

#2017
GM_MPG2017_df = MPG2017_df.loc[MPG2017_df['MfrName'].isin(["General Motors"])]
GM_MPG2017_df.columns = ['Year','mpg']
GM_MPG2017_df = GM_MPG2017_df.replace('General Motors','2017')

#2018
GM_MPG2018_df = MPG2018_df.loc[MPG2018_df['MfrName'].isin(["General Motors"])]
GM_MPG2018_df.columns = ['Year','mpg']
GM_MPG2018_df = GM_MPG2018_df.replace('General Motors','2018')

#2019
GM_MPG2019_df = MPG2019_df.loc[MPG2019_df['MfrName'].isin(["General Motors"])]
GM_MPG2019_df.columns = ['Year','mpg']
GM_MPG2019_df = GM_MPG2019_df.replace('General Motors','2019')

# %%
#General Motors
plt.figure(figsize=(20,6))                           # x axis = 20, y axis = 6
plt.ylim(10, 70)
all_df = pd.concat([GM_MPG2000_df,GM_MPG2001_df,GM_MPG2002_df,GM_MPG2003_df,GM_MPG2004_df,GM_MPG2005_df,GM_MPG2006_df,
                    GM_MPG2007_df,GM_MPG2008_df,GM_MPG2009_df,GM_MPG2010_df,GM_MPG2011_df,GM_MPG2012_df,
                   GM_MPG2013_df,GM_MPG2014_df,GM_MPG2015_df,GM_MPG2016_df,GM_MPG2016_df,GM_MPG2017_df,
                   GM_MPG2018_df,GM_MPG2019_df])
sns.boxplot(x="Year", y="mpg",data= all_df).set_title('General Motors')
# Out:
# Text(0.5, 1.0, 'General Motors')

# %%
#Chrysler Data
#2000
Chrysler_MPG2000_df = MPG2000_df.loc[MPG2000_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2000_df.columns = ['Year','mpg']
Chrysler_MPG2000_df = Chrysler_MPG2000_df.replace('Chrysler','2000')

#2001
Chrysler_MPG2001_df = MPG2001_df.loc[MPG2001_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2001_df.columns = ['Year','mpg']
Chrysler_MPG2001_df = Chrysler_MPG2001_df.replace('Chrysler','2001')

#2002
Chrysler_MPG2002_df = MPG2002_df.loc[MPG2002_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2002_df.columns = ['Year','mpg']
Chrysler_MPG2002_df = Chrysler_MPG2002_df.replace('Chrysler','2002')

#2003
Chrysler_MPG2003_df = MPG2003_df.loc[MPG2003_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2003_df.columns = ['Year','mpg']
Chrysler_MPG2003_df = Chrysler_MPG2003_df.replace('Chrysler','2003')

#2004
Chrysler_MPG2004_df = MPG2004_df.loc[MPG2004_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2004_df.columns = ['Year','mpg']
Chrysler_MPG2004_df = Chrysler_MPG2004_df.replace('Chrysler','2004')

#2005
Chrysler_MPG2005_df = MPG2005_df.loc[MPG2005_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2005_df.columns = ['Year','mpg']
Chrysler_MPG2005_df = Chrysler_MPG2005_df.replace('Chrysler','2005')

#2006
Chrysler_MPG2006_df = MPG2006_df.loc[MPG2006_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2006_df.columns = ['Year','mpg']
Chrysler_MPG2006_df = Chrysler_MPG2006_df.replace('Chrysler','2006')

#2007
Chrysler_MPG2007_df = MPG2007_df.loc[MPG2007_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2007_df.columns = ['Year','mpg']
Chrysler_MPG2007_df = Chrysler_MPG2007_df.replace('Chrysler','2007')

#2008
Chrysler_MPG2008_df = MPG2008_df.loc[MPG2008_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2008_df.columns = ['Year','mpg']
Chrysler_MPG2008_df = Chrysler_MPG2008_df.replace('Chrysler','2008')

#2009
Chrysler_MPG2009_df = MPG2009_df.loc[MPG2009_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2009_df.columns = ['Year','mpg']
Chrysler_MPG2009_df = Chrysler_MPG2009_df.replace('Chrysler','2009')

#2010
Chrysler_MPG2010_df = MPG2010_df.loc[MPG2010_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2010_df.columns = ['Year','mpg']
Chrysler_MPG2010_df = Chrysler_MPG2010_df.replace('Chrysler','2010')

#2011
Chrysler_MPG2011_df = MPG2011_df.loc[MPG2011_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2011_df.columns = ['Year','mpg']
Chrysler_MPG2011_df = Chrysler_MPG2011_df.replace('Chrysler','2011')

#2012
Chrysler_MPG2012_df = MPG2012_df.loc[MPG2012_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2012_df.columns = ['Year','mpg']
Chrysler_MPG2012_df = Chrysler_MPG2012_df.replace('Chrysler','2012')

#2013
Chrysler_MPG2013_df = MPG2013_df.loc[MPG2013_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2013_df.columns = ['Year','mpg']
Chrysler_MPG2013_df = Chrysler_MPG2013_df.replace('Chrysler','2013')

#2014
Chrysler_MPG2014_df = MPG2014_df.loc[MPG2014_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2014_df.columns = ['Year','mpg']
Chrysler_MPG2014_df = Chrysler_MPG2014_df.replace('Chrysler','2014')

#2015
Chrysler_MPG2015_df = MPG2015_df.loc[MPG2015_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2015_df.columns = ['Year','mpg']
Chrysler_MPG2015_df = Chrysler_MPG2015_df.replace('Chrysler','2015')

#2016
Chrysler_MPG2016_df = MPG2016_df.loc[MPG2016_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2016_df.columns = ['Year','mpg']
Chrysler_MPG2016_df = Chrysler_MPG2016_df.replace('Chrysler','2016')

#2017
Chrysler_MPG2017_df = MPG2017_df.loc[MPG2017_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2017_df.columns = ['Year','mpg']
Chrysler_MPG2017_df = Chrysler_MPG2017_df.replace('Chrysler','2017')

#2018
Chrysler_MPG2018_df = MPG2018_df.loc[MPG2018_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2018_df.columns = ['Year','mpg']
Chrysler_MPG2018_df = Chrysler_MPG2018_df.replace('Chrysler','2018')

#2019
Chrysler_MPG2019_df = MPG2019_df.loc[MPG2019_df['MfrName'].isin(["Chrysler"])]
Chrysler_MPG2019_df.columns = ['Year','mpg']
Chrysler_MPG2019_df = Chrysler_MPG2019_df.replace('Chrysler','2019')

# %%
plt.figure(figsize=(20,6))                           # x axis = 20, y axis = 6
plt.ylim(10, 70)
all_df = pd.concat([Chrysler_MPG2000_df,Chrysler_MPG2001_df,Chrysler_MPG2002_df,Chrysler_MPG2003_df,Chrysler_MPG2004_df,Chrysler_MPG2005_df,Chrysler_MPG2006_df,
                    Chrysler_MPG2007_df,Chrysler_MPG2008_df,Chrysler_MPG2009_df,Chrysler_MPG2010_df,Chrysler_MPG2011_df,Chrysler_MPG2012_df,
                   Chrysler_MPG2013_df,Chrysler_MPG2014_df,Chrysler_MPG2015_df,Chrysler_MPG2016_df,Chrysler_MPG2016_df,Chrysler_MPG2017_df,
                   Chrysler_MPG2018_df,Chrysler_MPG2019_df])
sns.boxplot(x="Year", y="mpg",data= all_df).set_title('Chrysler')
# Out:
# Text(0.5, 1.0, 'Chrysler')

# %%
#HONDA Data
#2000
HONDA_MPG2000_df = MPG2000_df.loc[MPG2000_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2000_df.columns = ['Year','mpg']
HONDA_MPG2000_df = HONDA_MPG2000_df.replace('HONDA','2000')

#2001
HONDA_MPG2001_df = MPG2001_df.loc[MPG2001_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2001_df.columns = ['Year','mpg']
HONDA_MPG2001_df = HONDA_MPG2001_df.replace('HONDA','2001')

#2002
HONDA_MPG2002_df = MPG2002_df.loc[MPG2002_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2002_df.columns = ['Year','mpg']
HONDA_MPG2002_df = HONDA_MPG2002_df.replace('HONDA','2002')

#2003
HONDA_MPG2003_df = MPG2003_df.loc[MPG2003_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2003_df.columns = ['Year','mpg']
HONDA_MPG2003_df = HONDA_MPG2003_df.replace('HONDA','2003')

#2004
HONDA_MPG2004_df = MPG2004_df.loc[MPG2004_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2004_df.columns = ['Year','mpg']
HONDA_MPG2004_df = HONDA_MPG2004_df.replace('HONDA','2004')

#2005
HONDA_MPG2005_df = MPG2005_df.loc[MPG2005_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2005_df.columns = ['Year','mpg']
HONDA_MPG2005_df = HONDA_MPG2005_df.replace('HONDA','2005')

#2006
HONDA_MPG2006_df = MPG2006_df.loc[MPG2006_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2006_df.columns = ['Year','mpg']
HONDA_MPG2006_df = HONDA_MPG2006_df.replace('HONDA','2006')

#2007
HONDA_MPG2007_df = MPG2007_df.loc[MPG2007_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2007_df.columns = ['Year','mpg']
HONDA_MPG2007_df = HONDA_MPG2007_df.replace('HONDA','2007')

#2008
HONDA_MPG2008_df = MPG2008_df.loc[MPG2008_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2008_df.columns = ['Year','mpg']
HONDA_MPG2008_df = HONDA_MPG2008_df.replace('HONDA','2008')

#2009
HONDA_MPG2009_df = MPG2009_df.loc[MPG2009_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2009_df.columns = ['Year','mpg']
HONDA_MPG2009_df = HONDA_MPG2009_df.replace('HONDA','2009')

#2010
HONDA_MPG2010_df = MPG2010_df.loc[MPG2010_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2010_df.columns = ['Year','mpg']
HONDA_MPG2010_df = HONDA_MPG2010_df.replace('HONDA','2010')

#2011
HONDA_MPG2011_df = MPG2011_df.loc[MPG2011_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2011_df.columns = ['Year','mpg']
HONDA_MPG2011_df = HONDA_MPG2011_df.replace('HONDA','2011')

#2012
HONDA_MPG2012_df = MPG2012_df.loc[MPG2012_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2012_df.columns = ['Year','mpg']
HONDA_MPG2012_df = HONDA_MPG2012_df.replace('HONDA','2012')

#2013
HONDA_MPG2013_df = MPG2013_df.loc[MPG2013_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2013_df.columns = ['Year','mpg']
HONDA_MPG2013_df = HONDA_MPG2013_df.replace('HONDA','2013')

#2014
HONDA_MPG2014_df = MPG2014_df.loc[MPG2014_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2014_df.columns = ['Year','mpg']
HONDA_MPG2014_df = HONDA_MPG2014_df.replace('HONDA','2014')

#2015
HONDA_MPG2015_df = MPG2015_df.loc[MPG2015_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2015_df.columns = ['Year','mpg']
HONDA_MPG2015_df = HONDA_MPG2015_df.replace('HONDA','2015')

#2016
HONDA_MPG2016_df = MPG2016_df.loc[MPG2016_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2016_df.columns = ['Year','mpg']
HONDA_MPG2016_df = HONDA_MPG2016_df.replace('HONDA','2016')

#2017
HONDA_MPG2017_df = MPG2017_df.loc[MPG2017_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2017_df.columns = ['Year','mpg']
HONDA_MPG2017_df = HONDA_MPG2017_df.replace('HONDA','2017')

#2018
HONDA_MPG2018_df = MPG2018_df.loc[MPG2018_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2018_df.columns = ['Year','mpg']
HONDA_MPG2018_df = HONDA_MPG2018_df.replace('HONDA','2018')

#2019
HONDA_MPG2019_df = MPG2019_df.loc[MPG2019_df['MfrName'].isin(["HONDA"])]
HONDA_MPG2019_df.columns = ['Year','mpg']
HONDA_MPG2019_df = HONDA_MPG2019_df.replace('HONDA','2019')

# %%
plt.figure(figsize=(20,6))                           # x axis = 20, y axis = 6
plt.ylim(10, 70)
all_df = pd.concat([HONDA_MPG2000_df,HONDA_MPG2001_df,HONDA_MPG2002_df,HONDA_MPG2003_df,HONDA_MPG2004_df,HONDA_MPG2005_df,HONDA_MPG2006_df,
                    HONDA_MPG2007_df,HONDA_MPG2008_df,HONDA_MPG2009_df,HONDA_MPG2010_df,HONDA_MPG2011_df,HONDA_MPG2012_df,
                   HONDA_MPG2013_df,HONDA_MPG2014_df,HONDA_MPG2015_df,HONDA_MPG2016_df,HONDA_MPG2016_df,HONDA_MPG2017_df,
                   HONDA_MPG2018_df,HONDA_MPG2019_df])
sns.boxplot(x="Year", y="mpg",data= all_df).set_title('HONDA')
# Out:
# Text(0.5, 1.0, 'HONDA')

# %%
#TOYOTA Data
#2000
TOYOTA_MPG2000_df = MPG2000_df.loc[MPG2000_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2000_df.columns = ['Year','mpg']
TOYOTA_MPG2000_df = TOYOTA_MPG2000_df.replace('TOYOTA','2000')

#2001
TOYOTA_MPG2001_df = MPG2001_df.loc[MPG2001_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2001_df.columns = ['Year','mpg']
TOYOTA_MPG2001_df = TOYOTA_MPG2001_df.replace('TOYOTA','2001')

#2002
TOYOTA_MPG2002_df = MPG2002_df.loc[MPG2002_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2002_df.columns = ['Year','mpg']
TOYOTA_MPG2002_df = TOYOTA_MPG2002_df.replace('TOYOTA','2002')

#2003
TOYOTA_MPG2003_df = MPG2003_df.loc[MPG2003_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2003_df.columns = ['Year','mpg']
TOYOTA_MPG2003_df = TOYOTA_MPG2003_df.replace('TOYOTA','2003')

#2004
TOYOTA_MPG2004_df = MPG2004_df.loc[MPG2004_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2004_df.columns = ['Year','mpg']
TOYOTA_MPG2004_df = TOYOTA_MPG2004_df.replace('TOYOTA','2004')

#2005
TOYOTA_MPG2005_df = MPG2005_df.loc[MPG2005_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2005_df.columns = ['Year','mpg']
TOYOTA_MPG2005_df = TOYOTA_MPG2005_df.replace('TOYOTA','2005')

#2006
TOYOTA_MPG2006_df = MPG2006_df.loc[MPG2006_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2006_df.columns = ['Year','mpg']
TOYOTA_MPG2006_df = TOYOTA_MPG2006_df.replace('TOYOTA','2006')

#2007
TOYOTA_MPG2007_df = MPG2007_df.loc[MPG2007_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2007_df.columns = ['Year','mpg']
TOYOTA_MPG2007_df = TOYOTA_MPG2007_df.replace('TOYOTA','2007')

#2008
TOYOTA_MPG2008_df = MPG2008_df.loc[MPG2008_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2008_df.columns = ['Year','mpg']
TOYOTA_MPG2008_df = TOYOTA_MPG2008_df.replace('TOYOTA','2008')

#2009
TOYOTA_MPG2009_df = MPG2009_df.loc[MPG2009_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2009_df.columns = ['Year','mpg']
TOYOTA_MPG2009_df = TOYOTA_MPG2009_df.replace('TOYOTA','2009')

#2010
TOYOTA_MPG2010_df = MPG2010_df.loc[MPG2010_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2010_df.columns = ['Year','mpg']
TOYOTA_MPG2010_df = TOYOTA_MPG2010_df.replace('TOYOTA','2010')

#2011
TOYOTA_MPG2011_df = MPG2011_df.loc[MPG2011_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2011_df.columns = ['Year','mpg']
TOYOTA_MPG2011_df = TOYOTA_MPG2011_df.replace('TOYOTA','2011')

#2012
TOYOTA_MPG2012_df = MPG2012_df.loc[MPG2012_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2012_df.columns = ['Year','mpg']
TOYOTA_MPG2012_df = TOYOTA_MPG2012_df.replace('TOYOTA','2012')

#2013
TOYOTA_MPG2013_df = MPG2013_df.loc[MPG2013_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2013_df.columns = ['Year','mpg']
TOYOTA_MPG2013_df = TOYOTA_MPG2013_df.replace('TOYOTA','2013')

#2014
TOYOTA_MPG2014_df = MPG2014_df.loc[MPG2014_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2014_df.columns = ['Year','mpg']
TOYOTA_MPG2014_df = TOYOTA_MPG2014_df.replace('TOYOTA','2014')

#2015
TOYOTA_MPG2015_df = MPG2015_df.loc[MPG2015_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2015_df.columns = ['Year','mpg']
TOYOTA_MPG2015_df = TOYOTA_MPG2015_df.replace('TOYOTA','2015')

#2016
TOYOTA_MPG2016_df = MPG2016_df.loc[MPG2016_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2016_df.columns = ['Year','mpg']
TOYOTA_MPG2016_df = TOYOTA_MPG2016_df.replace('TOYOTA','2016')

#2017
TOYOTA_MPG2017_df = MPG2017_df.loc[MPG2017_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2017_df.columns = ['Year','mpg']
TOYOTA_MPG2017_df = TOYOTA_MPG2017_df.replace('TOYOTA','2017')

#2018
TOYOTA_MPG2018_df = MPG2018_df.loc[MPG2018_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2018_df.columns = ['Year','mpg']
TOYOTA_MPG2018_df = TOYOTA_MPG2018_df.replace('TOYOTA','2018')

#2019
TOYOTA_MPG2019_df = MPG2019_df.loc[MPG2019_df['MfrName'].isin(["TOYOTA"])]
TOYOTA_MPG2019_df.columns = ['Year','mpg']
TOYOTA_MPG2019_df = TOYOTA_MPG2019_df.replace('TOYOTA','2019')

# %%
plt.figure(figsize=(20,6))                           # x axis = 20, y axis = 6
plt.ylim(10, 70)
all_df = pd.concat([TOYOTA_MPG2000_df,TOYOTA_MPG2001_df,TOYOTA_MPG2002_df,TOYOTA_MPG2003_df,TOYOTA_MPG2004_df,TOYOTA_MPG2005_df,TOYOTA_MPG2006_df,
                    TOYOTA_MPG2007_df,TOYOTA_MPG2008_df,TOYOTA_MPG2009_df,TOYOTA_MPG2010_df,TOYOTA_MPG2011_df,TOYOTA_MPG2012_df,
                   TOYOTA_MPG2013_df,TOYOTA_MPG2014_df,TOYOTA_MPG2015_df,TOYOTA_MPG2016_df,TOYOTA_MPG2016_df,TOYOTA_MPG2017_df,
                   TOYOTA_MPG2018_df,TOYOTA_MPG2019_df])
sns.boxplot(x="Year", y="mpg",data= all_df).set_title('TOYOTA')
# Out:
# Text(0.5, 1.0, 'TOYOTA')

# %% [markdown]
# Ans: GM, FORD, and Chrysler have drops in 2003. Also, the highest medians of them are in 2002. After 2003, the mpg gradually increases. HONDA and TOYOTA gradually increase until 2005. Then start to decrease, and the lowest mpg is in 2009. After that, the MPG gradually increase so far. Nowadays, Toyota is better than the past. Honda keeps its quality in recent years. GM, FORD, and Chrysler are aroud 20 or less than 20. Honda and Toyota are more than 20. Over these years, Honda is the best brand in fuel efficiency and its MPG is close to 30 in 2019.

# %% [markdown]
# 2. Plot the yearly mean in the years 2000- 2019 with conﬁdence interval of the mpg for each company. That is for each company compute the mean mpg over all vehicles sold by that company per year. What changes have there been in those years? How do the companies compare?

# %%
#General Motors
GM_MEAN_2000 = round(GM_MPG2000_df['mpg'].mean(),2)
GM_MEAN_2001 = round(GM_MPG2001_df['mpg'].mean(),2)
GM_MEAN_2002 = round(GM_MPG2002_df['mpg'].mean(),2)
GM_MEAN_2003 = round(GM_MPG2003_df['mpg'].mean(),2)
GM_MEAN_2004 = round(GM_MPG2004_df['mpg'].mean(),2)
GM_MEAN_2005 = round(GM_MPG2005_df['mpg'].mean(),2)
GM_MEAN_2006 = round(GM_MPG2006_df['mpg'].mean(),2)
GM_MEAN_2007 = round(GM_MPG2007_df['mpg'].mean(),2)
GM_MEAN_2008 = round(GM_MPG2008_df['mpg'].mean(),2)
GM_MEAN_2009 = round(GM_MPG2009_df['mpg'].mean(),2)
GM_MEAN_2010 = round(GM_MPG2010_df['mpg'].mean(),2)
GM_MEAN_2011 = round(GM_MPG2011_df['mpg'].mean(),2)
GM_MEAN_2012 = round(GM_MPG2012_df['mpg'].mean(),2)
GM_MEAN_2013 = round(GM_MPG2013_df['mpg'].mean(),2)
GM_MEAN_2014 = round(GM_MPG2014_df['mpg'].mean(),2)
GM_MEAN_2015 = round(GM_MPG2015_df['mpg'].mean(),2)
GM_MEAN_2016 = round(GM_MPG2016_df['mpg'].mean(),2)
GM_MEAN_2017 = round(GM_MPG2017_df['mpg'].mean(),2)
GM_MEAN_2018 = round(GM_MPG2018_df['mpg'].mean(),2)
GM_MEAN_2019 = round(GM_MPG2019_df['mpg'].mean(),2)

GM_Mean_all = pd.DataFrame({'Year':[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,
                                      2012,2013,2014,2015,2016,2017,2018,2019], 
                              'mpg':[GM_MEAN_2000,GM_MEAN_2001,GM_MEAN_2002,GM_MEAN_2003,
                                    GM_MEAN_2004,GM_MEAN_2005,GM_MEAN_2006,GM_MEAN_2007,
                                    GM_MEAN_2008,GM_MEAN_2009,GM_MEAN_2010,GM_MEAN_2011,
                                    GM_MEAN_2012,GM_MEAN_2013,GM_MEAN_2014,GM_MEAN_2015,
                                    GM_MEAN_2016,GM_MEAN_2017,GM_MEAN_2018,GM_MEAN_2019]})

ax =GM_Mean_all.plot(x='Year', y='mpg',ylim=(15,35),legend = False,figsize=(20,6),style='.-',xticks=GM_Mean_all['Year'], title='General Motors')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#FORD
FORD_MEAN_2000 = round(FORD_MPG2000_df['mpg'].mean(),2)
FORD_MEAN_2001 = round(FORD_MPG2001_df['mpg'].mean(),2)
FORD_MEAN_2002 = round(FORD_MPG2002_df['mpg'].mean(),2)
FORD_MEAN_2003 = round(FORD_MPG2003_df['mpg'].mean(),2)
FORD_MEAN_2004 = round(FORD_MPG2004_df['mpg'].mean(),2)
FORD_MEAN_2005 = round(FORD_MPG2005_df['mpg'].mean(),2)
FORD_MEAN_2006 = round(FORD_MPG2006_df['mpg'].mean(),2)
FORD_MEAN_2007 = round(FORD_MPG2007_df['mpg'].mean(),2)
FORD_MEAN_2008 = round(FORD_MPG2008_df['mpg'].mean(),2)
FORD_MEAN_2009 = round(FORD_MPG2009_df['mpg'].mean(),2)
FORD_MEAN_2010 = round(FORD_MPG2010_df['mpg'].mean(),2)
FORD_MEAN_2011 = round(FORD_MPG2011_df['mpg'].mean(),2)
FORD_MEAN_2012 = round(FORD_MPG2012_df['mpg'].mean(),2)
FORD_MEAN_2013 = round(FORD_MPG2013_df['mpg'].mean(),2)
FORD_MEAN_2014 = round(FORD_MPG2014_df['mpg'].mean(),2)
FORD_MEAN_2015 = round(FORD_MPG2015_df['mpg'].mean(),2)
FORD_MEAN_2016 = round(FORD_MPG2016_df['mpg'].mean(),2)
FORD_MEAN_2017 = round(FORD_MPG2017_df['mpg'].mean(),2)
FORD_MEAN_2018 = round(FORD_MPG2018_df['mpg'].mean(),2)
FORD_MEAN_2019 = round(FORD_MPG2019_df['mpg'].mean(),2)

FORD_Mean_all = pd.DataFrame({'Year':[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,
                                      2012,2013,2014,2015,2016,2017,2018,2019], 
                              'mpg':[FORD_MEAN_2000,FORD_MEAN_2001,FORD_MEAN_2002,FORD_MEAN_2003,
                                    FORD_MEAN_2004,FORD_MEAN_2005,FORD_MEAN_2006,FORD_MEAN_2007,
                                    FORD_MEAN_2008,FORD_MEAN_2009,FORD_MEAN_2010,FORD_MEAN_2011,
                                    FORD_MEAN_2012,FORD_MEAN_2013,FORD_MEAN_2014,FORD_MEAN_2015,
                                    FORD_MEAN_2016,FORD_MEAN_2017,FORD_MEAN_2018,FORD_MEAN_2019]})

ax =FORD_Mean_all.plot(x='Year', y='mpg',ylim=(15,35),legend = False,figsize=(20,6),style='.-',xticks=FORD_Mean_all['Year'], title='FORD')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#Chrysler
Chrysler_MEAN_2000 = round(Chrysler_MPG2000_df['mpg'].mean(),2)
Chrysler_MEAN_2001 = round(Chrysler_MPG2001_df['mpg'].mean(),2)
Chrysler_MEAN_2002 = round(Chrysler_MPG2002_df['mpg'].mean(),2)
Chrysler_MEAN_2003 = round(Chrysler_MPG2003_df['mpg'].mean(),2)
Chrysler_MEAN_2004 = round(Chrysler_MPG2004_df['mpg'].mean(),2)
Chrysler_MEAN_2005 = round(Chrysler_MPG2005_df['mpg'].mean(),2)
Chrysler_MEAN_2006 = round(Chrysler_MPG2006_df['mpg'].mean(),2)
Chrysler_MEAN_2007 = round(Chrysler_MPG2007_df['mpg'].mean(),2)
Chrysler_MEAN_2008 = round(Chrysler_MPG2008_df['mpg'].mean(),2)
Chrysler_MEAN_2009 = round(Chrysler_MPG2009_df['mpg'].mean(),2)
Chrysler_MEAN_2010 = round(Chrysler_MPG2010_df['mpg'].mean(),2)
Chrysler_MEAN_2011 = round(Chrysler_MPG2011_df['mpg'].mean(),2)
Chrysler_MEAN_2012 = round(Chrysler_MPG2012_df['mpg'].mean(),2)
Chrysler_MEAN_2013 = round(Chrysler_MPG2013_df['mpg'].mean(),2)
Chrysler_MEAN_2014 = round(Chrysler_MPG2014_df['mpg'].mean(),2)
Chrysler_MEAN_2015 = round(Chrysler_MPG2015_df['mpg'].mean(),2)
Chrysler_MEAN_2016 = round(Chrysler_MPG2016_df['mpg'].mean(),2)
Chrysler_MEAN_2017 = round(Chrysler_MPG2017_df['mpg'].mean(),2)
Chrysler_MEAN_2018 = round(Chrysler_MPG2018_df['mpg'].mean(),2)
Chrysler_MEAN_2019 = round(Chrysler_MPG2019_df['mpg'].mean(),2)

Chrysler_Mean_all = pd.DataFrame({'Year':[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,
                                      2012,2013,2014,2015,2016,2017,2018,2019], 
                              'mpg':[Chrysler_MEAN_2000,Chrysler_MEAN_2001,Chrysler_MEAN_2002,Chrysler_MEAN_2003,
                                    Chrysler_MEAN_2004,Chrysler_MEAN_2005,Chrysler_MEAN_2006,Chrysler_MEAN_2007,
                                    Chrysler_MEAN_2008,Chrysler_MEAN_2009,Chrysler_MEAN_2010,Chrysler_MEAN_2011,
                                    Chrysler_MEAN_2012,Chrysler_MEAN_2013,Chrysler_MEAN_2014,Chrysler_MEAN_2015,
                                    Chrysler_MEAN_2016,Chrysler_MEAN_2017,Chrysler_MEAN_2018,Chrysler_MEAN_2019]})

ax =Chrysler_Mean_all.plot(x='Year', y='mpg',ylim=(15,35),legend = False,figsize=(20,6),style='.-',xticks=Chrysler_Mean_all['Year'], title='Chrysler')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#HONDA
HONDA_MEAN_2000 = round(HONDA_MPG2000_df['mpg'].mean(),2)
HONDA_MEAN_2001 = round(HONDA_MPG2001_df['mpg'].mean(),2)
HONDA_MEAN_2002 = round(HONDA_MPG2002_df['mpg'].mean(),2)
HONDA_MEAN_2003 = round(HONDA_MPG2003_df['mpg'].mean(),2)
HONDA_MEAN_2004 = round(HONDA_MPG2004_df['mpg'].mean(),2)
HONDA_MEAN_2005 = round(HONDA_MPG2005_df['mpg'].mean(),2)
HONDA_MEAN_2006 = round(HONDA_MPG2006_df['mpg'].mean(),2)
HONDA_MEAN_2007 = round(HONDA_MPG2007_df['mpg'].mean(),2)
HONDA_MEAN_2008 = round(HONDA_MPG2008_df['mpg'].mean(),2)
HONDA_MEAN_2009 = round(HONDA_MPG2009_df['mpg'].mean(),2)
HONDA_MEAN_2010 = round(HONDA_MPG2010_df['mpg'].mean(),2)
HONDA_MEAN_2011 = round(HONDA_MPG2011_df['mpg'].mean(),2)
HONDA_MEAN_2012 = round(HONDA_MPG2012_df['mpg'].mean(),2)
HONDA_MEAN_2013 = round(HONDA_MPG2013_df['mpg'].mean(),2)
HONDA_MEAN_2014 = round(HONDA_MPG2014_df['mpg'].mean(),2)
HONDA_MEAN_2015 = round(HONDA_MPG2015_df['mpg'].mean(),2)
HONDA_MEAN_2016 = round(HONDA_MPG2016_df['mpg'].mean(),2)
HONDA_MEAN_2017 = round(HONDA_MPG2017_df['mpg'].mean(),2)
HONDA_MEAN_2018 = round(HONDA_MPG2018_df['mpg'].mean(),2)
HONDA_MEAN_2019 = round(HONDA_MPG2019_df['mpg'].mean(),2)

HONDA_Mean_all = pd.DataFrame({'Year':range(2000,2020), 
                              'mpg':[HONDA_MEAN_2000,HONDA_MEAN_2001,HONDA_MEAN_2002,HONDA_MEAN_2003,
                                    HONDA_MEAN_2004,HONDA_MEAN_2005,HONDA_MEAN_2006,HONDA_MEAN_2007,
                                    HONDA_MEAN_2008,HONDA_MEAN_2009,HONDA_MEAN_2010,HONDA_MEAN_2011,
                                    HONDA_MEAN_2012,HONDA_MEAN_2013,HONDA_MEAN_2014,HONDA_MEAN_2015,
                                    HONDA_MEAN_2016,HONDA_MEAN_2017,HONDA_MEAN_2018,HONDA_MEAN_2019]})

ax =HONDA_Mean_all.plot(x='Year', y='mpg',ylim=(15,35),legend = False,figsize=(20,6),style='.-',xticks=HONDA_Mean_all['Year'], title='HONDA')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#TOYOTA
TOYOTA_MEAN_2000 = round(TOYOTA_MPG2000_df['mpg'].mean(),2)
TOYOTA_MEAN_2001 = round(TOYOTA_MPG2001_df['mpg'].mean(),2)
TOYOTA_MEAN_2002 = round(TOYOTA_MPG2002_df['mpg'].mean(),2)
TOYOTA_MEAN_2003 = round(TOYOTA_MPG2003_df['mpg'].mean(),2)
TOYOTA_MEAN_2004 = round(TOYOTA_MPG2004_df['mpg'].mean(),2)
TOYOTA_MEAN_2005 = round(TOYOTA_MPG2005_df['mpg'].mean(),2)
TOYOTA_MEAN_2006 = round(TOYOTA_MPG2006_df['mpg'].mean(),2)
TOYOTA_MEAN_2007 = round(TOYOTA_MPG2007_df['mpg'].mean(),2)
TOYOTA_MEAN_2008 = round(TOYOTA_MPG2008_df['mpg'].mean(),2)
TOYOTA_MEAN_2009 = round(TOYOTA_MPG2009_df['mpg'].mean(),2)
TOYOTA_MEAN_2010 = round(TOYOTA_MPG2010_df['mpg'].mean(),2)
TOYOTA_MEAN_2011 = round(TOYOTA_MPG2011_df['mpg'].mean(),2)
TOYOTA_MEAN_2012 = round(TOYOTA_MPG2012_df['mpg'].mean(),2)
TOYOTA_MEAN_2013 = round(TOYOTA_MPG2013_df['mpg'].mean(),2)
TOYOTA_MEAN_2014 = round(TOYOTA_MPG2014_df['mpg'].mean(),2)
TOYOTA_MEAN_2015 = round(TOYOTA_MPG2015_df['mpg'].mean(),2)
TOYOTA_MEAN_2016 = round(TOYOTA_MPG2016_df['mpg'].mean(),2)
TOYOTA_MEAN_2017 = round(TOYOTA_MPG2017_df['mpg'].mean(),2)
TOYOTA_MEAN_2018 = round(TOYOTA_MPG2018_df['mpg'].mean(),2)
TOYOTA_MEAN_2019 = round(TOYOTA_MPG2019_df['mpg'].mean(),2)

TOYOTA_Mean_all = pd.DataFrame({'Year':range(2000,2020), 
                              'mpg':[TOYOTA_MEAN_2000,TOYOTA_MEAN_2001,TOYOTA_MEAN_2002,TOYOTA_MEAN_2003,
                                    TOYOTA_MEAN_2004,TOYOTA_MEAN_2005,TOYOTA_MEAN_2006,TOYOTA_MEAN_2007,
                                    TOYOTA_MEAN_2008,TOYOTA_MEAN_2009,TOYOTA_MEAN_2010,TOYOTA_MEAN_2011,
                                    TOYOTA_MEAN_2012,TOYOTA_MEAN_2013,TOYOTA_MEAN_2014,TOYOTA_MEAN_2015,
                                    TOYOTA_MEAN_2016,TOYOTA_MEAN_2017,TOYOTA_MEAN_2018,TOYOTA_MEAN_2019]})

# ax =TOYOTA_Mean_all.plot(x='Year', y='mpg',ylim=(15,35),legend = False,figsize=(20,6),style='.-',xticks=TOYOTA_Mean_all['Year'], title='TOYOTA')
# ax.set_ylabel("mpg")

# sns.lmplot(x='Year', y='mpg', data =TOYOTA_Mean_all)
sns.lmplot(x='Year', y='mpg', data =TOYOTA_Mean_all, aspect=3, height=6)
ax = plt.gca()
ax.set_title("TOYOTA")
# Out:
# Text(0.5, 1.0, 'TOYOTA')

# %% [markdown]
# 2. Mean fuel efficiency
# Ans: GM, FORD, and Chrysler have peaks in 2002, but drop in 2003. Moreover, their MPGs drop again around 2008. After 2009, their MPGs start to increase gradually. Nowadays, their MPGs reach around 20. Honda has a big drop in 2008. It drops from 32 to 25. After that, Honda gradually increase to 27.5. Toyota dropped a little in 2008, and then increased a little per year. It's around 25.
# The plots of mean fuel efficiency is similar to the botplots. They show that the most efficient brand is Honda over those years.

# %% [markdown]
# 3. Plot the mpg for each company per year of their most fuel efﬁcient vehicle each year. What changes have there been in those years? How do the companies compare?

# %%
#General Motors
GM_MAX_2000 = round(GM_MPG2000_df['mpg'].max(),2)
GM_MAX_2001 = round(GM_MPG2001_df['mpg'].max(),2)
GM_MAX_2002 = round(GM_MPG2002_df['mpg'].max(),2)
GM_MAX_2003 = round(GM_MPG2003_df['mpg'].max(),2)
GM_MAX_2004 = round(GM_MPG2004_df['mpg'].max(),2)
GM_MAX_2005 = round(GM_MPG2005_df['mpg'].max(),2)
GM_MAX_2006 = round(GM_MPG2006_df['mpg'].max(),2)
GM_MAX_2007 = round(GM_MPG2007_df['mpg'].max(),2)
GM_MAX_2008 = round(GM_MPG2008_df['mpg'].max(),2)
GM_MAX_2009 = round(GM_MPG2009_df['mpg'].max(),2)
GM_MAX_2010 = round(GM_MPG2010_df['mpg'].max(),2)
GM_MAX_2011 = round(GM_MPG2011_df['mpg'].max(),2)
GM_MAX_2012 = round(GM_MPG2012_df['mpg'].max(),2)
GM_MAX_2013 = round(GM_MPG2013_df['mpg'].max(),2)
GM_MAX_2014 = round(GM_MPG2014_df['mpg'].max(),2)
GM_MAX_2015 = round(GM_MPG2015_df['mpg'].max(),2)
GM_MAX_2016 = round(GM_MPG2016_df['mpg'].max(),2)
GM_MAX_2017 = round(GM_MPG2017_df['mpg'].max(),2)
GM_MAX_2018 = round(GM_MPG2018_df['mpg'].max(),2)
GM_MAX_2019 = round(GM_MPG2019_df['mpg'].max(),2)

GM_Mean_all = pd.DataFrame({'Year':[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,
                                      2012,2013,2014,2015,2016,2017,2018,2019], 
                              'mpg':[GM_MAX_2000,GM_MAX_2001,GM_MAX_2002,GM_MAX_2003,
                                    GM_MAX_2004,GM_MAX_2005,GM_MAX_2006,GM_MAX_2007,
                                    GM_MAX_2008,GM_MAX_2009,GM_MAX_2010,GM_MAX_2011,
                                    GM_MAX_2012,GM_MAX_2013,GM_MAX_2014,GM_MAX_2015,
                                    GM_MAX_2016,GM_MAX_2017,GM_MAX_2018,GM_MAX_2019]})

ax =GM_Mean_all.plot(x='Year', y='mpg',ylim=(25,70),legend = False,figsize=(20,6),style='.-',xticks=GM_Mean_all['Year'], title='General Motors')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#FORD
FORD_MAX_2000 = round(FORD_MPG2000_df['mpg'].max(),2)
FORD_MAX_2001 = round(FORD_MPG2001_df['mpg'].max(),2)
FORD_MAX_2002 = round(FORD_MPG2002_df['mpg'].max(),2)
FORD_MAX_2003 = round(FORD_MPG2003_df['mpg'].max(),2)
FORD_MAX_2004 = round(FORD_MPG2004_df['mpg'].max(),2)
FORD_MAX_2005 = round(FORD_MPG2005_df['mpg'].max(),2)
FORD_MAX_2006 = round(FORD_MPG2006_df['mpg'].max(),2)
FORD_MAX_2007 = round(FORD_MPG2007_df['mpg'].max(),2)
FORD_MAX_2008 = round(FORD_MPG2008_df['mpg'].max(),2)
FORD_MAX_2009 = round(FORD_MPG2009_df['mpg'].max(),2)
FORD_MAX_2010 = round(FORD_MPG2010_df['mpg'].max(),2)
FORD_MAX_2011 = round(FORD_MPG2011_df['mpg'].max(),2)
FORD_MAX_2012 = round(FORD_MPG2012_df['mpg'].max(),2)
FORD_MAX_2013 = round(FORD_MPG2013_df['mpg'].max(),2)
FORD_MAX_2014 = round(FORD_MPG2014_df['mpg'].max(),2)
FORD_MAX_2015 = round(FORD_MPG2015_df['mpg'].max(),2)
FORD_MAX_2016 = round(FORD_MPG2016_df['mpg'].max(),2)
FORD_MAX_2017 = round(FORD_MPG2017_df['mpg'].max(),2)
FORD_MAX_2018 = round(FORD_MPG2018_df['mpg'].max(),2)
FORD_MAX_2019 = round(FORD_MPG2019_df['mpg'].max(),2)

FORD_MAX_all = pd.DataFrame({'Year':range(2000,2020), 
                              'mpg':[FORD_MAX_2000,FORD_MAX_2001,FORD_MAX_2002,FORD_MAX_2003,
                                    FORD_MAX_2004,FORD_MAX_2005,FORD_MAX_2006,FORD_MAX_2007,
                                    FORD_MAX_2008,FORD_MAX_2009,FORD_MAX_2010,FORD_MAX_2011,
                                    FORD_MAX_2012,FORD_MAX_2013,FORD_MAX_2014,FORD_MAX_2015,
                                    FORD_MAX_2016,FORD_MAX_2017,FORD_MAX_2018,FORD_MAX_2019]})

ax =FORD_MAX_all.plot(x='Year', y='mpg',ylim=(25,70),legend = False,figsize=(20,6),style='.-',xticks=FORD_MAX_all['Year'], title='FORD')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#Chrysler
Chrysler_MAX_2000 = round(Chrysler_MPG2000_df['mpg'].max(),2)
Chrysler_MAX_2001 = round(Chrysler_MPG2001_df['mpg'].max(),2)
Chrysler_MAX_2002 = round(Chrysler_MPG2002_df['mpg'].max(),2)
Chrysler_MAX_2003 = round(Chrysler_MPG2003_df['mpg'].max(),2)
Chrysler_MAX_2004 = round(Chrysler_MPG2004_df['mpg'].max(),2)
Chrysler_MAX_2005 = round(Chrysler_MPG2005_df['mpg'].max(),2)
Chrysler_MAX_2006 = round(Chrysler_MPG2006_df['mpg'].max(),2)
Chrysler_MAX_2007 = round(Chrysler_MPG2007_df['mpg'].max(),2)
Chrysler_MAX_2008 = round(Chrysler_MPG2008_df['mpg'].max(),2)
Chrysler_MAX_2009 = round(Chrysler_MPG2009_df['mpg'].max(),2)
Chrysler_MAX_2010 = round(Chrysler_MPG2010_df['mpg'].max(),2)
Chrysler_MAX_2011 = round(Chrysler_MPG2011_df['mpg'].max(),2)
Chrysler_MAX_2012 = round(Chrysler_MPG2012_df['mpg'].max(),2)
Chrysler_MAX_2013 = round(Chrysler_MPG2013_df['mpg'].max(),2)
Chrysler_MAX_2014 = round(Chrysler_MPG2014_df['mpg'].max(),2)
Chrysler_MAX_2015 = round(Chrysler_MPG2015_df['mpg'].max(),2)
Chrysler_MAX_2016 = round(Chrysler_MPG2016_df['mpg'].max(),2)
Chrysler_MAX_2017 = round(Chrysler_MPG2017_df['mpg'].max(),2)
Chrysler_MAX_2018 = round(Chrysler_MPG2018_df['mpg'].max(),2)
Chrysler_MAX_2019 = round(Chrysler_MPG2019_df['mpg'].max(),2)

Chrysler_MAX_all = pd.DataFrame({'Year':range(2000,2020), 
                              'mpg':[Chrysler_MAX_2000,Chrysler_MAX_2001,Chrysler_MAX_2002,Chrysler_MAX_2003,
                                    Chrysler_MAX_2004,Chrysler_MAX_2005,Chrysler_MAX_2006,Chrysler_MAX_2007,
                                    Chrysler_MAX_2008,Chrysler_MAX_2009,Chrysler_MAX_2010,Chrysler_MAX_2011,
                                    Chrysler_MAX_2012,Chrysler_MAX_2013,Chrysler_MAX_2014,Chrysler_MAX_2015,
                                    Chrysler_MAX_2016,Chrysler_MAX_2017,Chrysler_MAX_2018,Chrysler_MAX_2019]})

ax =Chrysler_MAX_all.plot(x='Year', y='mpg',ylim=(25,70),legend = False,figsize=(20,6),style='.-',xticks=Chrysler_MAX_all['Year'], title='Chrysler')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#HONDA
HONDA_MAX_2000 = round(HONDA_MPG2000_df['mpg'].max(),2)
HONDA_MAX_2001 = round(HONDA_MPG2001_df['mpg'].max(),2)
HONDA_MAX_2002 = round(HONDA_MPG2002_df['mpg'].max(),2)
HONDA_MAX_2003 = round(HONDA_MPG2003_df['mpg'].max(),2)
HONDA_MAX_2004 = round(HONDA_MPG2004_df['mpg'].max(),2)
HONDA_MAX_2005 = round(HONDA_MPG2005_df['mpg'].max(),2)
HONDA_MAX_2006 = round(HONDA_MPG2006_df['mpg'].max(),2)
HONDA_MAX_2007 = round(HONDA_MPG2007_df['mpg'].max(),2)
HONDA_MAX_2008 = round(HONDA_MPG2008_df['mpg'].max(),2)
HONDA_MAX_2009 = round(HONDA_MPG2009_df['mpg'].max(),2)
HONDA_MAX_2010 = round(HONDA_MPG2010_df['mpg'].max(),2)
HONDA_MAX_2011 = round(HONDA_MPG2011_df['mpg'].max(),2)
HONDA_MAX_2012 = round(HONDA_MPG2012_df['mpg'].max(),2)
HONDA_MAX_2013 = round(HONDA_MPG2013_df['mpg'].max(),2)
HONDA_MAX_2014 = round(HONDA_MPG2014_df['mpg'].max(),2)
HONDA_MAX_2015 = round(HONDA_MPG2015_df['mpg'].max(),2)
HONDA_MAX_2016 = round(HONDA_MPG2016_df['mpg'].max(),2)
HONDA_MAX_2017 = round(HONDA_MPG2017_df['mpg'].max(),2)
HONDA_MAX_2018 = round(HONDA_MPG2018_df['mpg'].max(),2)
HONDA_MAX_2019 = round(HONDA_MPG2019_df['mpg'].max(),2)

HONDA_MAX_all = pd.DataFrame({'Year':range(2000,2020), 
                              'mpg':[HONDA_MAX_2000,HONDA_MAX_2001,HONDA_MAX_2002,HONDA_MAX_2003,
                                    HONDA_MAX_2004,HONDA_MAX_2005,HONDA_MAX_2006,HONDA_MAX_2007,
                                    HONDA_MAX_2008,HONDA_MAX_2009,HONDA_MAX_2010,HONDA_MAX_2011,
                                    HONDA_MAX_2012,HONDA_MAX_2013,HONDA_MAX_2014,HONDA_MAX_2015,
                                    HONDA_MAX_2016,HONDA_MAX_2017,HONDA_MAX_2018,HONDA_MAX_2019]})

ax =HONDA_MAX_all.plot(x='Year', y='mpg',ylim=(25,70),legend = False,figsize=(20,6),style='.-',xticks=HONDA_MAX_all['Year'], title='HONDA')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
#TOYOTA
TOYOTA_MAX_2000 = round(TOYOTA_MPG2000_df['mpg'].max(),2)
TOYOTA_MAX_2001 = round(TOYOTA_MPG2001_df['mpg'].max(),2)
TOYOTA_MAX_2002 = round(TOYOTA_MPG2002_df['mpg'].max(),2)
TOYOTA_MAX_2003 = round(TOYOTA_MPG2003_df['mpg'].max(),2)
TOYOTA_MAX_2004 = round(TOYOTA_MPG2004_df['mpg'].max(),2)
TOYOTA_MAX_2005 = round(TOYOTA_MPG2005_df['mpg'].max(),2)
TOYOTA_MAX_2006 = round(TOYOTA_MPG2006_df['mpg'].max(),2)
TOYOTA_MAX_2007 = round(TOYOTA_MPG2007_df['mpg'].max(),2)
TOYOTA_MAX_2008 = round(TOYOTA_MPG2008_df['mpg'].max(),2)
TOYOTA_MAX_2009 = round(TOYOTA_MPG2009_df['mpg'].max(),2)
TOYOTA_MAX_2010 = round(TOYOTA_MPG2010_df['mpg'].max(),2)
TOYOTA_MAX_2011 = round(TOYOTA_MPG2011_df['mpg'].max(),2)
TOYOTA_MAX_2012 = round(TOYOTA_MPG2012_df['mpg'].max(),2)
TOYOTA_MAX_2013 = round(TOYOTA_MPG2013_df['mpg'].max(),2)
TOYOTA_MAX_2014 = round(TOYOTA_MPG2014_df['mpg'].max(),2)
TOYOTA_MAX_2015 = round(TOYOTA_MPG2015_df['mpg'].max(),2)
TOYOTA_MAX_2016 = round(TOYOTA_MPG2016_df['mpg'].max(),2)
TOYOTA_MAX_2017 = round(TOYOTA_MPG2017_df['mpg'].max(),2)
TOYOTA_MAX_2018 = round(TOYOTA_MPG2018_df['mpg'].max(),2)
TOYOTA_MAX_2019 = round(TOYOTA_MPG2019_df['mpg'].max(),2)

TOYOTA_MAX_all = pd.DataFrame({'Year':range(2000,2020), 
                              'mpg':[TOYOTA_MAX_2000,TOYOTA_MAX_2001,TOYOTA_MAX_2002,TOYOTA_MAX_2003,
                                    TOYOTA_MAX_2004,TOYOTA_MAX_2005,TOYOTA_MAX_2006,TOYOTA_MAX_2007,
                                    TOYOTA_MAX_2008,TOYOTA_MAX_2009,TOYOTA_MAX_2010,TOYOTA_MAX_2011,
                                    TOYOTA_MAX_2012,TOYOTA_MAX_2013,TOYOTA_MAX_2014,TOYOTA_MAX_2015,
                                    TOYOTA_MAX_2016,TOYOTA_MAX_2017,TOYOTA_MAX_2018,TOYOTA_MAX_2019]})
ax =TOYOTA_MAX_all.plot(x='Year', y='mpg',ylim=(25,70),legend = False,figsize=(20,6),style='.-',xticks=TOYOTA_MAX_all['Year'], title='TOYOTA')
ax.set_ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %% [markdown]
# 3.most fuel efficiency.
# Ans: GM dropped in 2003, and had a huge improvement in 2016. FORD increased gradually until 2013. The most fuel efficent vehicle of FORD hasn't changed for 7 years. Chrysler's max MPGs don't have a lot of different. Yet, during 2006 to 2011, mpgs are a little less than other years. Max mpgs of Honda change a lot over those years. MPGs of Toyota are much stabler than other brands. Though Honda changed a lot, the most fuel efficient vehiche is Honda for each year.

# %%
causes_of_death_path = './assignment2Data/causes_of_death.csv'
framingham_path = './assignment2Data/framingham.csv'

# %%
#Issue 2 Diet and Death
# CauseOfDeath_df = pd.read_csv(causes_of_death_path,usecols =[1,9])
CauseOfDeath_df = pd.read_csv(causes_of_death_path)
# Framingham_df = pd.read_csv(framingham_path,usecols =[1,2])
Framingham_df = pd.read_csv(framingham_path)

# %%
#Accidents
accidents_df = CauseOfDeath_df.loc[CauseOfDeath_df['Cause'].isin(["Accidents"])]
accidents_df
accidents_df.plot(x='Year', y='Age Adjusted Death Rate',figsize=(20,6), style='.-',legend = False).set_ylabel("Death Rate")
# Out:
# Text(0, 0.5, 'Death Rate')

# %%
#Cancer
Cancer_df = CauseOfDeath_df.loc[CauseOfDeath_df['Cause'].isin(["Cancer"])]
Cancer_df.plot(x='Year', y='Age Adjusted Death Rate',figsize=(20,6), style='.-',legend = False).set_ylabel("Death Rate")

# %%
#Heart Disease
Heart_Disease_df = CauseOfDeath_df.loc[CauseOfDeath_df['Cause'].isin(["Heart Disease"])]
Heart_Disease_df.plot(x='Year', y='Age Adjusted Death Rate',figsize=(20,6), style='.-',legend = False)

# %%
#Influenza and Pneumonia
Influenza_Pneumonia_df = CauseOfDeath_df.loc[CauseOfDeath_df['Cause'].isin(['Influenza and Pneumonia'])]
# Heart_Disease_df
Influenza_Pneumonia_df.plot(x='Year', y='Age Adjusted Death Rate',figsize=(20,6), style='.-',legend = False).set_ylabel("Death Rate")
# Out:
# Text(0, 0.5, 'Death Rate')

# %%
#IStroke
Stroke_df = CauseOfDeath_df.loc[CauseOfDeath_df['Cause'].isin(['Stroke'])]
# Heart_Disease_df
Stroke_df.plot(x='Year', y='Age Adjusted Death Rate',figsize=(20,6), style='.-',legend = False).set_ylabel("Death Rate")
# Out:
# Text(0, 0.5, 'Death Rate')

# %% [markdown]
# 4. What is the percentage of people in the study that have diabetes?
# Now we need to compare this to the general population. Either a person is diagnosed as having diabetes or not. We can use the multinomial distribution to generate a sample of two values. Say we have an event that has .75 probability of occurring. Then the following will count the number of times the event does not occur and not occur in a sample of 1000.
# two_value_probabilities = [0.25, 0.75]
# sample_size = 1000
# np.random.multinomial(sample_size, two_value_probabilities)
# Using this we can compute the number of people we would expect to have diabetes in a sam-
# ple of 5,000, which we need to convert to a percentage. Now do this 200 times.

# %%
two_value_probabilities = [0.25, 0.75]
sample_size = 1000
np.random.multinomial(sample_size, two_value_probabilities)
# Out:
# array([262, 738])

# %% [markdown]
# 5. Produce the histogram of the percent of people in your 200 samples with diabetes.

# %% [markdown]
# 6. Compute the 95% conﬁdence interval of the 200 values in #5

# %% [markdown]
# 7. Is the study representative of the general population? Why or why not?
# In the ﬁle framingham.csv the column TOTCHOL gives the total cholesterol of each person in the study. The column ANYCHD indicates if the person has any heard disease.

# %% [markdown]
# 8. Plot the cholesterol values for the people with heart disease, for the people with out heart
# disease.

# %% [markdown]
# 9. Compute the 95% conﬁdence interval of the cholesterol values for the people with heart disease, for the people with out heart disease.

# %% [markdown]
# 10.What can we deduce about cholesterol values and heart disease?
